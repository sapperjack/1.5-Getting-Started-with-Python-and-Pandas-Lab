# %% [markdown]
# # Lab Instructions
#
# Find a dataset that interests you. I'd recommend starting on [Kaggle](https://www.kaggle.com/). Read through all of the material about the dataset and download a .CSV file.
#
# 1. Write a short summary of the data.  Where did it come from?  How was it collected?  What are the features in the data?  Why is this dataset interesting to you?
#
# 2. Identify 5 interesting questions about your data that you can answer using Pandas methods.
#
# 3. Answer those questions!  You may use any method you want (including LLMs) to help you write your code; however, you should use Pandas to find the answers.  LLMs will not always write code in this way without specific instruction.
#
# 4. Write the answer to your question in a text box underneath the code you used to calculate the answer.

# %% [markdown]
# The dataset I selected is the IMDB Movie Dataset. The dataset was obtained from Kaggle and contains information about movies, including ratings, genres, release years, votes, and other movie-related features. The data was collected from IMDb, one of the largest online movie databases.
#
# Some of the features included in the dataset are movie title, genre, release year, IMDb rating, and vote count. These features allow us to analyze trends in movie popularity and ratings.
#
# This dataset is interesting to me because I enjoy watching movies and learning what factors contribute to a movie's success. By analyzing the data, I can identify trends in ratings, genres, and popularity among different movies.
#
#
#
# Question 2: Five Questions
# What is the average IMDb rating of all movies?
# Which movie has the highest IMDb rating?
# Which genre appears most frequently in the dataset?
# What is the average rating for each genre?
# Which year had the highest average movie rating?

# %%
import pandas as pd

df = pd.read_csv('IMDB_Dataset_Cleaned.csv')

df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend  o...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
Question 1

How many positive and negative reviews are there?
# Out:
#   Cell In[3], line 1
#     Question 1
#              ^
# SyntaxError: invalid syntax

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
Question 2

What percentage of reviews are positive?
# Out:
#   Cell In[5], line 1
#     Question 2
#              ^
# SyntaxError: invalid syntax

# %%
(df['sentiment'].value_counts(normalize=True) * 100)
# Out:
# sentiment
# positive    50.0
# negative    50.0
# Name: proportion, dtype: float64

# %%
Question 3

What is the average review length for positive reviews?
df['review_length'] = df['review'].str.len()

df[df['sentiment'] == 'positive']['review_length'].mean()
# Out:
#   Cell In[7], line 1
#     Question 3
#              ^
# SyntaxError: invalid syntax

# %%
df['review_length'] = df['review'].str.len()

df[df['sentiment'] == 'positive']['review_length'].mean()
# Out:
# np.float64(1277.3942)

# %%
df[df['sentiment'] == 'negative']['review_length'].mean()
# Out:
# np.float64(1242.3752)

# %%
df.groupby('sentiment')['review_length'].mean()
# Out:
# sentiment
# negative    1242.3752
# positive    1277.3942
# Name: review_length, dtype: float64

# %%
he dataset I selected is the IMDB Movie Review Dataset from Kaggle. The dataset contains movie reviews and their associated sentiment labels, either positive or negative. The data was collected from IMDb user reviews and prepared for sentiment analysis tasks.

The dataset contains two main features: the review text and the sentiment classification. The review column contains written movie reviews, while the sentiment column indicates whether the review is positive or negative.

This dataset is interesting to me because I enjoy movies and wanted to see how people express positive and negative opinions in movie reviews. It also provides a good introduction to text analysis using Pandas.
